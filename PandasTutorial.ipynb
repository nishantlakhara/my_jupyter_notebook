# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name": ['harry', 'rohan', 'skillf', 'shubh'],
    "marks": [92, 34, 24, 17],
    "city": ['rampur', 'kolkata', 'barailly', 'antarctica']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks        city
# 0   harry     92      rampur
# 1   rohan     34     kolkata
# 2  skillf     24    barailly
# 3   shubh     17  antarctica

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv', index=False)

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %%
df.tail(2)
# Out:
#      name  marks        city
# 2  skillf     24    barailly
# 3   shubh     17  antarctica

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
harry = pd.read_csv('harry.csv')

# %%
harry
# Out:
#    Train No  Speed        City
# 0     12322     34      rampur
# 1     12534    123     kolkata
# 2    125654     67    bareilly
# 3    564523     87  antarctica

# %%
harry['Speed']
# Out:
# 0     34
# 1    123
# 2     67
# 3     87
# Name: Speed, dtype: int64

# %%
harry['Speed'][0]
# Out:
# 34

# %%
harry['Speed'][0] = 50
# Out:
# c:\users\nishant\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
harry
# Out:
#    Train No  Speed        City
# 0     12322     50      rampur
# 1     12534    123     kolkata
# 2    125654     67    bareilly
# 3    564523     87  antarctica

# %%
harry.to_csv('harry.csv')

# %%
harry.index = ['First', 'Second', 'Third', 'Fourth']

# %%
harry
# Out:
#         Train No  Speed        City
# First      12322     50      rampur
# Second     12534    123     kolkata
# Third     125654     67    bareilly
# Fourth    564523     87  antarctica

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.720526
# 1     0.837039
# 2     0.779005
# 3     0.911832
# 4     0.356409
# 5     0.339400
# 6     0.713005
# 7     0.786829
# 8     0.267575
# 9     0.572446
# 10    0.094217
# 11    0.631128
# 12    0.363594
# 13    0.461502
# 14    0.941684
# 15    0.513212
# 16    0.901462
# 17    0.385153
# 18    0.621514
# 19    0.698288
# 20    0.747746
# 21    0.115488
# 22    0.572881
# 23    0.380821
# 24    0.946590
# 25    0.295240
# 26    0.497387
# 27    0.867570
# 28    0.019780
# 29    0.766500
# 30    0.003739
# 31    0.168589
# 32    0.018329
# 33    0.038067
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index=np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.688829  0.453999  0.407355  0.238269  0.940830
# 1  0.335974  0.930101  0.451883  0.811087  0.799529
# 2  0.897948  0.974108  0.249655  0.310118  0.847494
# 3  0.101697  0.572738  0.719358  0.302205  0.991587
# 4  0.160059  0.478778  0.135052  0.288981  0.129642

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.688829  0.453999  0.407355  0.238269  0.940830
# 1    0.335974  0.930101  0.451883  0.811087  0.799529
# 2    0.897948  0.974108  0.249655  0.310118  0.847494
# 3    0.101697  0.572738  0.719358  0.302205  0.991587
# 4    0.160059  0.478778  0.135052  0.288981  0.129642
# ..        ...       ...       ...       ...       ...
# 329  0.816356  0.134892  0.003189  0.146733  0.201148
# 330  0.615703  0.814650  0.518276  0.069091  0.536335
# 331  0.620113  0.458648  0.790915  0.008840  0.914576
# 332  0.036708  0.491108  0.150558  0.825443  0.446964
# 333  0.457213  0.570152  0.122613  0.577518  0.788350
#
# [334 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0.492026    0.497481    0.513091    0.503318    0.502112
# std      0.288196    0.285859    0.285347    0.295052    0.292829
# min      0.000191    0.000816    0.002033    0.002208    0.004100
# 25%      0.241871    0.252733    0.274681    0.254586    0.232574
# 50%      0.481191    0.493256    0.511025    0.515020    0.496638
# 75%      0.755941    0.735620    0.765534    0.766112    0.753914
# max      0.990824    0.996164    0.994261    0.996982    0.999005

# %%
newdf.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf[0][0] =
appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0      9783  0.453999  0.407355  0.238269  0.940830
# 1  0.335974  0.930101  0.451883  0.811087  0.799529
# 2  0.897948  0.974108  0.249655  0.310118  0.847494
# 3  0.101697  0.572738  0.719358  0.302205  0.991587
# 4  0.160059  0.478778  0.135052  0.288981  0.129642

# %%
newdf3.head()
# Out:
#           0         1         2         3         4
# 0     97835  0.453999  0.407355  0.238269  0.940830
# 1  0.335974  0.930101  0.451883  0.811087  0.799529
# 2  0.897948  0.974108  0.249655  0.310118  0.847494
# 3  0.101697  0.572738  0.719358  0.302205  0.991587
# 4  0.160059  0.478778  0.135052  0.288981  0.129642

# %%
newdf.loc[0,0] = 654

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0       654  0.453999  0.407355  0.238269  0.940830
# 1  0.335974  0.930101  0.451883  0.811087  0.799529

# %%
newdf.columns = list("ABCDE")

# %%
newdf
# Out:
#             A         B         C         D         E
# 0         654  0.453999  0.407355  0.238269  0.940830
# 1    0.335974  0.930101  0.451883  0.811087  0.799529
# 2    0.897948  0.974108  0.249655  0.310118  0.847494
# 3    0.101697  0.572738  0.719358  0.302205  0.991587
# 4    0.160059  0.478778  0.135052  0.288981  0.129642
# ..        ...       ...       ...       ...       ...
# 329  0.816356  0.134892  0.003189  0.146733  0.201148
# 330  0.615703  0.814650  0.518276  0.069091  0.536335
# 331  0.620113  0.458648  0.790915  0.008840  0.914576
# 332  0.036708  0.491108  0.150558  0.825443  0.446964
# 333  0.457213  0.570152  0.122613  0.577518  0.788350
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,0] = 654

# %%
newdf
# Out:
#             A         B         C         D         E      0
# 0         654  0.453999  0.407355  0.238269  0.940830  654.0
# 1    0.335974  0.930101  0.451883  0.811087  0.799529    NaN
# 2    0.897948  0.974108  0.249655  0.310118  0.847494    NaN
# 3    0.101697  0.572738  0.719358  0.302205  0.991587    NaN
# 4    0.160059  0.478778  0.135052  0.288981  0.129642    NaN
# ..        ...       ...       ...       ...       ...    ...
# 329  0.816356  0.134892  0.003189  0.146733  0.201148    NaN
# 330  0.615703  0.814650  0.518276  0.069091  0.536335    NaN
# 331  0.620113  0.458648  0.790915  0.008840  0.914576    NaN
# 332  0.036708  0.491108  0.150558  0.825443  0.446964    NaN
# 333  0.457213  0.570152  0.122613  0.577518  0.788350    NaN
#
# [334 rows x 6 columns]

# %%
newdf.loc[0,'A'] = 65445

# %%
newdf
# Out:
#             A         B         C         D         E      0
# 0       65445  0.453999  0.407355  0.238269  0.940830  654.0
# 1    0.335974  0.930101  0.451883  0.811087  0.799529    NaN
# 2    0.897948  0.974108  0.249655  0.310118  0.847494    NaN
# 3    0.101697  0.572738  0.719358  0.302205  0.991587    NaN
# 4    0.160059  0.478778  0.135052  0.288981  0.129642    NaN
# ..        ...       ...       ...       ...       ...    ...
# 329  0.816356  0.134892  0.003189  0.146733  0.201148    NaN
# 330  0.615703  0.814650  0.518276  0.069091  0.536335    NaN
# 331  0.620113  0.458648  0.790915  0.008840  0.914576    NaN
# 332  0.036708  0.491108  0.150558  0.825443  0.446964    NaN
# 333  0.457213  0.570152  0.122613  0.577518  0.788350    NaN
#
# [334 rows x 6 columns]

# %%
newdf.drop(0)
# Out:
#             A         B         C         D         E   0
# 1    0.335974  0.930101  0.451883  0.811087  0.799529 NaN
# 2    0.897948  0.974108  0.249655  0.310118  0.847494 NaN
# 3    0.101697  0.572738  0.719358  0.302205  0.991587 NaN
# 4    0.160059  0.478778  0.135052  0.288981  0.129642 NaN
# 5     0.15915  0.776116  0.770000  0.015583  0.305919 NaN
# ..        ...       ...       ...       ...       ...  ..
# 329  0.816356  0.134892  0.003189  0.146733  0.201148 NaN
# 330  0.615703  0.814650  0.518276  0.069091  0.536335 NaN
# 331  0.620113  0.458648  0.790915  0.008840  0.914576 NaN
# 332  0.036708  0.491108  0.150558  0.825443  0.446964 NaN
# 333  0.457213  0.570152  0.122613  0.577518  0.788350 NaN
#
# [333 rows x 6 columns]

# %%
newdf = newdf.drop(0, axis=1)

# %%
newdf.head()
# Out:
#           A         B         C         D         E      0
# 0     65445  0.453999  0.407355  0.238269  0.940830  654.0
# 1  0.335974  0.930101  0.451883  0.811087  0.799529    NaN
# 2  0.897948  0.974108  0.249655  0.310118  0.847494    NaN
# 3  0.101697  0.572738  0.719358  0.302205  0.991587    NaN
# 4  0.160059  0.478778  0.135052  0.288981  0.129642    NaN

# %%
newdf.loc[[1,2], ['C','D']]
# Out:
#           C         D
# 1  0.451883  0.811087
# 2  0.249655  0.310118

# %%
newdf.head()
# Out:
#           A         B         C         D         E
# 0     65445  0.453999  0.407355  0.238269  0.940830
# 1  0.335974  0.930101  0.451883  0.811087  0.799529
# 2  0.897948  0.974108  0.249655  0.310118  0.847494
# 3  0.101697  0.572738  0.719358  0.302205  0.991587
# 4  0.160059  0.478778  0.135052  0.288981  0.129642

# %%
newdf.loc[:, ['C','D']]
# Out:
#             C         D
# 0    0.407355  0.238269
# 1    0.451883  0.811087
# 2    0.249655  0.310118
# 3    0.719358  0.302205
# 4    0.135052  0.288981
# ..        ...       ...
# 329  0.003189  0.146733
# 330  0.518276  0.069091
# 331  0.790915  0.008840
# 332  0.150558  0.825443
# 333  0.122613  0.577518
#
# [334 rows x 2 columns]

# %%
newdf.loc[[1,2], :]
# Out:
#           A         B         C         D         E
# 1  0.335974  0.930101  0.451883  0.811087  0.799529
# 2  0.897948  0.974108  0.249655  0.310118  0.847494

# %%
newdf.loc[(newdf['A']<0.3) & (newdf['C']>0.1)]
# Out:
#             A         B         C         D         E
# 3    0.101697  0.572738  0.719358  0.302205  0.991587
# 4    0.160059  0.478778  0.135052  0.288981  0.129642
# 5     0.15915  0.776116  0.770000  0.015583  0.305919
# 6    0.225428  0.204852  0.279627  0.717815  0.849838
# 8    0.038666  0.470434  0.648620  0.629966  0.944982
# ..        ...       ...       ...       ...       ...
# 320  0.032424  0.355491  0.739057  0.813838  0.561484
# 322  0.070634  0.996164  0.133575  0.873014  0.573577
# 323  0.010243  0.540372  0.814577  0.492085  0.382408
# 324  0.231119  0.695817  0.818518  0.729649  0.683226
# 332  0.036708  0.491108  0.150558  0.825443  0.446964
#
# [93 rows x 5 columns]

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0     65445  0.453999  0.407355  0.238269  0.940830
# 1  0.335974  0.930101  0.451883  0.811087  0.799529

# %%
#For number and not name
newdf.iloc[0,4]
# Out:
# 0.9408297937016726

# %%
newdf.iloc[[0,1], [1,2]]
# Out:
#           B         C
# 0  0.453999  0.407355
# 1  0.930101  0.451883

# %%
newdf.head(3)
# Out:
#           A         B         C         D         E
# 0     65445  0.453999  0.407355  0.238269  0.940830
# 1  0.335974  0.930101  0.451883  0.811087  0.799529
# 2  0.897948  0.974108  0.249655  0.310118  0.847494

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.335974  0.930101  0.451883  0.811087  0.799529
# 2    0.897948  0.974108  0.249655  0.310118  0.847494
# 3    0.101697  0.572738  0.719358  0.302205  0.991587
# 4    0.160059  0.478778  0.135052  0.288981  0.129642
# 5     0.15915  0.776116  0.770000  0.015583  0.305919
# ..        ...       ...       ...       ...       ...
# 329  0.816356  0.134892  0.003189  0.146733  0.201148
# 330  0.615703  0.814650  0.518276  0.069091  0.536335
# 331  0.620113  0.458648  0.790915  0.008840  0.914576
# 332  0.036708  0.491108  0.150558  0.825443  0.446964
# 333  0.457213  0.570152  0.122613  0.577518  0.788350
#
# [333 rows x 5 columns]

# %%
newdf.drop(['A','D'], axis=1, inplace=True)

# %%
newdf
# Out:
#             B         C         E
# 0    0.453999  0.407355  0.940830
# 1    0.930101  0.451883  0.799529
# 2    0.974108  0.249655  0.847494
# 3    0.572738  0.719358  0.991587
# 4    0.478778  0.135052  0.129642
# ..        ...       ...       ...
# 329  0.134892  0.003189  0.201148
# 330  0.814650  0.518276  0.536335
# 331  0.458648  0.790915  0.914576
# 332  0.491108  0.150558  0.446964
# 333  0.570152  0.122613  0.788350
#
# [334 rows x 3 columns]

# %%
newdf.drop([1,5], axis=0, inplace=True)

# %%
newdf
# Out:
#             B         C         E
# 0    0.453999  0.407355  0.940830
# 2    0.974108  0.249655  0.847494
# 3    0.572738  0.719358  0.991587
# 4    0.478778  0.135052  0.129642
# 6    0.204852  0.279627  0.849838
# ..        ...       ...       ...
# 329  0.134892  0.003189  0.201148
# 330  0.814650  0.518276  0.536335
# 331  0.458648  0.790915  0.914576
# 332  0.491108  0.150558  0.446964
# 333  0.570152  0.122613  0.788350
#
# [332 rows x 3 columns]

# %%
newdf.reset_index()
# Out:
#             B         C         E
# 0    0.453999  0.407355  0.940830
# 1    0.974108  0.249655  0.847494
# 2    0.572738  0.719358  0.991587
# 3    0.478778  0.135052  0.129642
# 4    0.204852  0.279627  0.849838
# ..        ...       ...       ...
# 327  0.134892  0.003189  0.201148
# 328  0.814650  0.518276  0.536335
# 329  0.458648  0.790915  0.914576
# 330  0.491108  0.150558  0.446964
# 331  0.570152  0.122613  0.788350
#
# [332 rows x 3 columns]

# %%
newdf
# Out:
#             B         C         E
# 0    0.453999  0.407355  0.940830
# 1    0.974108  0.249655  0.847494
# 2    0.572738  0.719358  0.991587
# 3    0.478778  0.135052  0.129642
# 4    0.204852  0.279627  0.849838
# ..        ...       ...       ...
# 327  0.134892  0.003189  0.201148
# 328  0.814650  0.518276  0.536335
# 329  0.458648  0.790915  0.914576
# 330  0.491108  0.150558  0.446964
# 331  0.570152  0.122613  0.788350
#
# [332 rows x 3 columns]

# %%
newdf.reset_index(drop=True, inplace=True)
# Out:
#             B         C         E
# 0    0.453999  0.407355  0.940830
# 1    0.974108  0.249655  0.847494
# 2    0.572738  0.719358  0.991587
# 3    0.478778  0.135052  0.129642
# 4    0.204852  0.279627  0.849838
# ..        ...       ...       ...
# 327  0.134892  0.003189  0.201148
# 328  0.814650  0.518276  0.536335
# 329  0.458648  0.790915  0.914576
# 330  0.491108  0.150558  0.446964
# 331  0.570152  0.122613  0.788350
#
# [332 rows x 3 columns]

# %%
newdf.head()
# Out:
#           B         C         E
# 0  0.453999  0.407355  0.940830
# 1  0.974108  0.249655  0.847494
# 2  0.572738  0.719358  0.991587
# 3  0.478778  0.135052  0.129642
# 4  0.204852  0.279627  0.849838

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: B, Length: 332, dtype: bool

# %%
newdf['B'] = None

# %%
newdf
# Out:
#         B         C         E
# 0    None  0.407355  0.940830
# 1    None  0.249655  0.847494
# 2    None  0.719358  0.991587
# 3    None  0.135052  0.129642
# 4    None  0.279627  0.849838
# ..    ...       ...       ...
# 327  None  0.003189  0.201148
# 328  None  0.518276  0.536335
# 329  None  0.790915  0.914576
# 330  None  0.150558  0.446964
# 331  None  0.122613  0.788350
#
# [332 rows x 3 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 327    True
# 328    True
# 329    True
# 330    True
# 331    True
# Name: B, Length: 332, dtype: bool

# %%
newdf.loc[:,['B']] = None

# %%
newdf.head()
# Out:
#       B         C         E
# 0  None  0.407355  0.940830
# 1  None  0.249655  0.847494
# 2  None  0.719358  0.991587
# 3  None  0.135052  0.129642
# 4  None  0.279627  0.849838

# %%
df = pd.DataFrame({
    "name" : ["Alfred", "Batman", "Catwoman", np.nan, "Alfred"],
    "toy": [np.nan, 'Batmobile', 'Bullwhip', np.nan, "A"],
    "born": [pd.NaT, pd.Timestamp("1940-04-25"), pd.NaT, pd.NaT, pd.NaT]
})

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# 3       NaN        NaN        NaT
# 4    Alfred          A        NaT

# %%
#If any single value is null
df.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %%
df.dropna(how="all")
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# 4    Alfred          A        NaT

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# 3       NaN        NaN        NaT
# 4    Alfred          A        NaT

# %%
df.drop_duplicates(subset=['name'])
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# 3       NaN        NaN        NaT

# %%
df.drop_duplicates(subset=['name'], keep='last')
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# 3       NaN        NaN        NaT
# 4    Alfred          A        NaT

# %%
df.drop_duplicates(subset=['name'], keep=False)
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT
# 3       NaN        NaN        NaT

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    4 non-null      object
#  1   toy     3 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 248.0+ bytes

# %%
df['name'].value_counts(dropna=False)
# Out:
# Alfred      2
# NaN         1
# Batman      1
# Catwoman    1
# Name: name, dtype: int64

# %%
df['toy'].value_counts(dropna=False)
# Out:
# NaN          2
# A            1
# Batmobile    1
# Bullwhip     1
# Name: toy, dtype: int64

# %%
df['toy'].value_counts(dropna=True)
# Out:
# A            1
# Batmobile    1
# Bullwhip     1
# Name: toy, dtype: int64

# %%
df.notnull()
# Out:
#     name    toy   born
# 0   True  False  False
# 1   True   True   True
# 2   True   True  False
# 3  False  False  False
# 4   True   True  False

# %%
df.isnull()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True
# 3   True   True   True
# 4  False  False   True

# %%
#create a dataframe which contains only integers with 3 rows and 2 columns
#run following dataframe methods on them:
df.describe()
df.mean()
df.corr()
df.count()
df.max()
df.min()
df.median()
df.std()
# Out:
# c:\users\nishant\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   This is separate from the ipykernel package so we can avoid doing imports until
# c:\users\nishant\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   after removing the cwd from sys.path.
# c:\users\nishant\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:9: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   if __name__ == '__main__':
# born   NaT
# dtype: timedelta64[ns]
